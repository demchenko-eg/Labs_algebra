# %% [markdown]
# # Лабораторна робота 6
#
# ## Завдання 1
#
# В групі рухів правильного восьмикутника задайте циклічну підгрупу порядку 4. Побудуйте для неї ліві і праві класи суміжності та перевірте чи буде ця група нормальною.

# %%
D8 = DihedralGroup(8)
g = D8((1,2,3,4,5,6,7,8))
H = D8.subgroup([g])
H_elements = H.list()
left_cosets = D8.cosets(H, side='left')
right_cosets = D8.cosets(H, side='right')
is_normal = H.is_normal(D8)
H_elements, left_cosets, right_cosets, is_normal
# Out:
# ([(),
#   (1,2,3,4,5,6,7,8),
#   (1,3,5,7)(2,4,6,8),
#   (1,4,7,2,5,8,3,6),
#   (1,5)(2,6)(3,7)(4,8),
#   (1,6,3,8,5,2,7,4),
#   (1,7,5,3)(2,8,6,4),
#   (1,8,7,6,5,4,3,2)],
#  [[(),
#    (1,2,3,4,5,6,7,8),
#    (1,3,5,7)(2,4,6,8),
#    (1,4,7,2,5,8,3,6),
#    (1,5)(2,6)(3,7)(4,8),
#    (1,6,3,8,5,2,7,4),
#    (1,7,5,3)(2,8,6,4),
#    (1,8,7,6,5,4,3,2)],
#   [(2,8)(3,7)(4,6),
#    (1,2)(3,8)(4,7)(5,6),
#    (1,3)(4,8)(5,7),
#    (1,4)(2,3)(5,8)(6,7),
#    (1,5)(2,4)(6,8),
#    (1,6)(2,5)(3,4)(7,8),
#    (1,7)(2,6)(3,5),
#    (1,8)(2,7)(3,6)(4,5)]],
#  [[(),
#    (1,2,3,4,5,6,7,8),
#    (1,3,5,7)(2,4,6,8),
#    (1,4,7,2,5,8,3,6),
#    (1,5)(2,6)(3,7)(4,8),
#    (1,6,3,8,5,2,7,4),
#    (1,7,5,3)(2,8,6,4),
#    (1,8,7,6,5,4,3,2)],
#   [(2,8)(3,7)(4,6),
#    (1,8)(2,7)(3,6)(4,5),
#    (1,7)(2,6)(3,5),
#    (1,6)(2,5)(3,4)(7,8),
#    (1,5)(2,4)(6,8),
#    (1,4)(2,3)(5,8)(6,7),
#    (1,3)(4,8)(5,7),
#    (1,2)(3,8)(4,7)(5,6)]],
#  True)

# %% [markdown]
# ## Завдання 2
#
# Переберіть всі підгрупи знакозмінної групи $A_5$. Перевірте всі на нормальність. Порівняйте час роботи з методом `.is_simple` для групи $A_5$.

# %%
A5 = AlternatingGroup(5)
subgroups = A5.subgroups()
normal_subgroups = [H for H in subgroups if H.is_normal(A5)]
is_simple_check = A5.is_simple()
len(subgroups), normal_subgroups, is_simple_check
# Out:
# (59,
#  [Subgroup generated by [()] of (Alternating group of order 5!/2 as a permutation group),
#   Subgroup generated by [(2,4)(3,5), (1,2,5)] of (Alternating group of order 5!/2 as a permutation group)],
#  True)

# %% [markdown]
# ## Завдання 3
#
# Задайте кілька діедральних груп $D_n$ для різних $n$. Як варіант, переберіть n в межах $3 \le n \le 100$. Для кожної діедральної групи побудуйте __список порядків нормальних підгруп__ (методом `normal_subgroups`). Знайдіть закономірність і виведіть гіпотезу.
#
# Спрогнозуйте скільки нормальних підгруп має група $D_{470448}$ __без виводу всіх за допомогою Sage__. _Опишіть_ всі нормальні підгрупи групи $D_{470448}$.

# %%
results = {}
for n in range(3, 101):
    D_n = DihedralGroup(n)
    normal_subgroups = D_n.normal_subgroups()
    orders = [H.order() for H in normal_subgroups]
    results[n] = orders
results
# Out:
# {3: [6, 3, 1],
#  4: [8, 4, 4, 4, 2, 1],
#  5: [10, 5, 1],
#  6: [12, 6, 6, 6, 2, 3, 1],
#  7: [14, 7, 1],
#  8: [16, 8, 8, 8, 4, 2, 1],
#  9: [18, 9, 3, 1],
#  10: [20, 10, 10, 10, 2, 5, 1],
#  11: [22, 11, 1],
#  12: [24, 12, 12, 12, 6, 4, 2, 3, 1],
#  13: [26, 13, 1],
#  14: [28, 14, 14, 14, 2, 7, 1],
#  15: [30, 15, 3, 5, 1],
#  16: [32, 16, 16, 16, 8, 4, 2, 1],
#  17: [34, 17, 1],
#  18: [36, 18, 18, 18, 6, 9, 2, 3, 1],
#  19: [38, 19, 1],
#  20: [40, 20, 20, 20, 10, 4, 2, 5, 1],
#  21: [42, 21, 3, 7, 1],
#  22: [44, 22, 22, 22, 2, 11, 1],
#  23: [46, 23, 1],
#  24: [48, 24, 24, 24, 12, 6, 8, 4, 2, 3, 1],
#  25: [50, 25, 5, 1],
#  26: [52, 26, 26, 26, 2, 13, 1],
#  27: [54, 27, 9, 3, 1],
#  28: [56, 28, 28, 28, 14, 4, 2, 7, 1],
#  29: [58, 29, 1],
#  30: [60, 30, 30, 30, 10, 15, 6, 2, 3, 5, 1],
#  31: [62, 31, 1],
#  32: [64, 32, 32, 32, 16, 8, 4, 2, 1],
#  33: [66, 33, 3, 11, 1],
#  34: [68, 34, 34, 34, 2, 17, 1],
#  35: [70, 35, 5, 7, 1],
#  36: [72, 36, 36, 36, 18, 12, 6, 9, 4, 2, 3, 1],
#  37: [74, 37, 1],
#  38: [76, 38, 38, 38, 2, 19, 1],
#  39: [78, 39, 3, 13, 1],
#  40: [80, 40, 40, 40, 20, 10, 8, 4, 2, 5, 1],
#  41: [82, 41, 1],
#  42: [84, 42, 42, 42, 14, 21, 6, 2, 3, 7, 1],
#  43: [86, 43, 1],
#  44: [88, 44, 44, 44, 22, 4, 2, 11, 1],
#  45: [90, 45, 15, 9, 3, 5, 1],
#  46: [92, 46, 46, 46, 2, 23, 1],
#  47: [94, 47, 1],
#  48: [96, 48, 48, 48, 24, 12, 6, 16, 8, 4, 2, 3, 1],
#  49: [98, 49, 7, 1],
#  50: [100, 50, 50, 50, 10, 25, 2, 5, 1],
#  51: [102, 51, 3, 17, 1],
#  52: [104, 52, 52, 52, 26, 4, 2, 13, 1],
#  53: [106, 53, 1],
#  54: [108, 54, 54, 54, 18, 27, 6, 9, 2, 3, 1],
#  55: [110, 55, 5, 11, 1],
#  56: [112, 56, 56, 56, 28, 14, 8, 4, 2, 7, 1],
#  57: [114, 57, 3, 19, 1],
#  58: [116, 58, 58, 58, 2, 29, 1],
#  59: [118, 59, 1],
#  60: [120, 60, 60, 60, 30, 20, 10, 15, 12, 6, 4, 2, 3, 5, 1],
#  61: [122, 61, 1],
#  62: [124, 62, 62, 62, 2, 31, 1],
#  63: [126, 63, 21, 9, 3, 7, 1],
#  64: [128, 64, 64, 64, 32, 16, 8, 4, 2, 1],
#  65: [130, 65, 5, 13, 1],
#  66: [132, 66, 66, 66, 22, 33, 6, 2, 3, 11, 1],
#  67: [134, 67, 1],
#  68: [136, 68, 68, 68, 34, 4, 2, 17, 1],
#  69: [138, 69, 3, 23, 1],
#  70: [140, 70, 70, 70, 14, 35, 10, 2, 5, 7, 1],
#  71: [142, 71, 1],
#  72: [144, 72, 72, 72, 36, 18, 24, 12, 6, 9, 8, 4, 2, 3, 1],
#  73: [146, 73, 1],
#  74: [148, 74, 74, 74, 2, 37, 1],
#  75: [150, 75, 15, 25, 3, 5, 1],
#  76: [152, 76, 76, 76, 38, 4, 2, 19, 1],
#  77: [154, 77, 7, 11, 1],
#  78: [156, 78, 78, 78, 26, 39, 6, 2, 3, 13, 1],
#  79: [158, 79, 1],
#  80: [160, 80, 80, 80, 40, 20, 10, 16, 8, 4, 2, 5, 1],
#  81: [162, 81, 27, 9, 3, 1],
#  82: [164, 82, 82, 82, 2, 41, 1],
#  83: [166, 83, 1],
#  84: [168, 84, 84, 84, 42, 28, 14, 21, 12, 6, 4, 2, 3, 7, 1],
#  85: [170, 85, 5, 17, 1],
#  86: [172, 86, 86, 86, 2, 43, 1],
#  87: [174, 87, 3, 29, 1],
#  88: [176, 88, 88, 88, 44, 22, 8, 4, 2, 11, 1],
#  89: [178, 89, 1],
#  90: [180, 90, 90, 90, 30, 45, 10, 15, 18, 6, 9, 2, 3, 5, 1],
#  91: [182, 91, 7, 13, 1],
#  92: [184, 92, 92, 92, 46, 4, 2, 23, 1],
#  93: [186, 93, 3, 31, 1],
#  94: [188, 94, 94, 94, 2, 47, 1],
#  95: [190, 95, 5, 19, 1],
#  96: [192, 96, 96, 96, 48, 24, 12, 6, 32, 16, 8, 4, 2, 3, 1],
#  97: [194, 97, 1],
#  98: [196, 98, 98, 98, 14, 49, 2, 7, 1],
#  99: [198, 99, 33, 9, 3, 11, 1],
#  100: [200, 100, 100, 100, 50, 20, 10, 25, 4, 2, 5, 1]}

# %% [markdown]
# ## Завдання 4
#
# На сайті https://brauer.maths.qmul.ac.uk/Atlas/v3/spor/HS в секції `Representations of HS : Number of Points 100` знайдіть у форматі GAP генератори $G = \langle a, b \rangle$. Задайте їх як елементи групи $S_{100}$ і породіть ними підгрупу $G$. Це так звана Higman-Sims група. Виведіть її порядок і знайдіть нормальні підгрупи. Зробіть висновки.

# %%
a = PermutationGroupElement("........")
b = PermutationGroupElement("........")
S100 = SymmetricGroup(100)
G = S100.subgroup([a, b])
order_G = G.order()
normal_subgroups = G.normal_subgroups()
order_G, normal_subgroups
# Out:
# Traceback (most recent call last):
#
#   File /ext/sage/10.4/local/var/lib/sage/venv-python3.12.4/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3550 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[7], line 1
#     a = PermutationGroupElement("........")
#
#   File /ext/sage/10.4/src/sage/groups/perm_gps/constructor.py:117 in PermutationGroupElement
#     v = standardize_generator(g, None)
#
#   File /ext/sage/10.4/src/sage/groups/perm_gps/constructor.py:250 in standardize_generator
#     g = string_to_tuples(g)
#
#   File /ext/sage/10.4/src/sage/groups/perm_gps/constructor.py:148 in string_to_tuples
#     return sage_eval(g, preparse=False)
#
#   File /ext/sage/10.4/src/sage/misc/sage_eval.py:200 in sage_eval
#     return eval(source, sage.all.__dict__, locals)
#
#   File <string>:1
#     [........]
#      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
